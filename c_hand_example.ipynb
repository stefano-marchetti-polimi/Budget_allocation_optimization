# %% [markdown]
# # Coastal flood inundation mapping workflow

# %% [markdown]
# ### [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/passah2o/pygeoflood/blob/master/doc/examples/c_hand_example.ipynb)
#
# On Google Colab, run the following commands to install pygeoflood and other dependencies:
#
# ```bash
# %pip install git+https://github.com/passah2o/pygeoflood
# %pip install contextily matplotlib-scalebar
# ```

# %%
pip install git+https://github.com/passah2o/pygeoflood
# Out:
# Collecting git+https://github.com/passah2o/pygeoflood
#   Cloning https://github.com/passah2o/pygeoflood to /tmp/pip-req-build-__a_h94z
#   Running command git clone --filter=blob:none --quiet https://github.com/passah2o/pygeoflood /tmp/pip-req-build-__a_h94z
#   Resolved https://github.com/passah2o/pygeoflood to commit e271a9f28c5bdd431dbe3ed16817fb6eee81fc79
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (1.1.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (6.17.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (3.10.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (2.2.2)
# Collecting rasterio (from pygeoflood==0.0.3a2)
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting scikit-fmm (from pygeoflood==0.0.3a2)
#   Downloading scikit_fmm-2025.6.23.tar.gz (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.8/467.8 kB 12.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (1.16.2)
# Collecting whitebox (from pygeoflood==0.0.3a2)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pygeoflood==0.0.3a2) (2025.9.1)
# Collecting fiona (from pygeoflood==0.0.3a2)
#   Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from fiona->pygeoflood==0.0.3a2) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from fiona->pygeoflood==0.0.3a2) (2025.8.3)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.12/dist-packages (from fiona->pygeoflood==0.0.3a2) (8.3.0)
# Collecting click-plugins>=1.0 (from fiona->pygeoflood==0.0.3a2)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting cligj>=0.5 (from fiona->pygeoflood==0.0.3a2)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->pygeoflood==0.0.3a2) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas->pygeoflood==0.0.3a2) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->pygeoflood==0.0.3a2) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->pygeoflood==0.0.3a2) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pygeoflood==0.0.3a2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pygeoflood==0.0.3a2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pygeoflood==0.0.3a2) (2025.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygeoflood==0.0.3a2) (5.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pygeoflood==0.0.3a2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pygeoflood==0.0.3a2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pygeoflood==0.0.3a2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pygeoflood==0.0.3a2) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pygeoflood==0.0.3a2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pygeoflood==0.0.3a2) (3.2.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->pygeoflood==0.0.3a2) (0.43.0)
# Collecting affine (from rasterio->pygeoflood==0.0.3a2)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pygeoflood==0.0.3a2) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pygeoflood==0.0.3a2) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pygeoflood==0.0.3a2) (2025.9.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->pygeoflood==0.0.3a2) (0.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->pygeoflood==0.0.3a2) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->pygeoflood==0.0.3a2) (5.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pygeoflood==0.0.3a2) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->pygeoflood==0.0.3a2) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->pygeoflood==0.0.3a2) (0.2.14)
# Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 77.4 MB/s eta 0:00:00
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 69.6 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.8 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.9 MB/s eta 0:00:00
# Building wheels for collected packages: pygeoflood, scikit-fmm
#   Building wheel for pygeoflood (pyproject.toml) ... done
#   Created wheel for pygeoflood: filename=pygeoflood-0.0.3a2-py3-none-any.whl size=242710 sha256=595322d3663d613fcb72e1cb60db131d6069027bb0e1e617db601ec9bff91d84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8bblpy84/wheels/9e/d5/f4/13d28d9e5ba386a40b1358921c5797b762e5a8c7ae10078317
#   Building wheel for scikit-fmm (pyproject.toml) ... done
#   Created wheel for scikit-fmm: filename=scikit_fmm-2025.6.23-cp312-cp312-linux_x86_64.whl size=76989 sha256=7b8c0f2a65bac341e6f4e9c66bf292a9ffd811bedb45b1c3516a749bab7db0e6
#   Stored in directory: /root/.cache/pip/wheels/77/56/c6/af81fbdd8d07f64d50a73fe825d9195579de59292c0411fae8
# Successfully built pygeoflood scikit-fmm
# Installing collected packages: whitebox, scikit-fmm, jedi, cligj, click-plugins, affine, rasterio, fiona, pygeoflood
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 fiona-1.10.1 jedi-0.19.2 pygeoflood-0.0.3a2 rasterio-1.4.3 scikit-fmm-2025.6.23 whitebox-2.3.6

# %%
pip install contextily matplotlib-scalebar
# Out:
# Collecting contextily
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting matplotlib-scalebar
#   Downloading matplotlib_scalebar-0.9.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from contextily) (3.10.0)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from contextily) (11.3.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from contextily) (1.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from contextily) (2.32.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily) (1.5.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from contextily) (2025.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily) (2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.12/dist-packages (from mercantile->contextily) (8.3.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (2025.8.3)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio->contextily) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->contextily) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->contextily) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading matplotlib_scalebar-0.9.0-py3-none-any.whl (16 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: mercantile, matplotlib-scalebar, contextily
# Successfully installed contextily-1.6.2 matplotlib-scalebar-0.9.0 mercantile-1.2.1

# %% [markdown]
# ### Import libraries

# %%
from pathlib import Path
from pygeoflood import pyGeoFlood

# %% [markdown]
# ### Download example data if necessary
# Resulting directory structure and file sizes:
# ```
# data
# ├── aoi_coastline.geojson [5.7M]
# └── houston_example_DEM_30m.tif [121M]

# %%
# %%bash
#
# # places input datasets in data directory whether or not it exists
# if [ -d "data" ]; then
#   cd data
#   curl -sL https://utexas.box.com/shared/static/sx0n3rncb191nuwokqjpmu14yo38pw61.tgz | tar --strip-components=1 -xzvf -
# else
#   curl -sL https://utexas.box.com/shared/static/sx0n3rncb191nuwokqjpmu14yo38pw61.tgz | tar -xzvf -
# fi
# Out:
# data/
# data/aoi_coastline.geojson
# data/houston_example_DEM_30m.tif

# %% [markdown]
# ### Instantiate **pygeoflood** model class

# %%
pgf = pyGeoFlood(dem_path="data/houston_example_DEM_30m.tif")

# %% [markdown]
# ### Show DEM with ocean pixel location

# %%
import contextily as cx
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import rasterio as rio

from matplotlib_scalebar.scalebar import ScaleBar
from mpl_toolkits.axes_grid1 import make_axes_locatable
from rasterio.features import geometry_mask
from rasterio.plot import plotting_extent
from skimage.measure import label


def plot_raster(raster=None, profile=None, label=None, **kwargs):
    fig, ax = plt.subplots(dpi=200)

    # show inundation map
    im = ax.imshow(
        raster,
        extent=plotting_extent(raster, profile["transform"]),
        zorder=2,
        **kwargs,
    )

    # add colorbar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.10)
    fig.colorbar(im, cax=cax, label=label)

    # add basemap
    cx.add_basemap(
        ax,
        crs=profile["crs"],
        source=cx.providers.Esri.WorldImagery,
        zoom=10,
        attribution_size=2,
        zorder=1,
    )

    # add scalebar
    ax.add_artist(ScaleBar(1, box_alpha=0, location="lower right", color="white"))

    # add north arrow
    x, y, arrow_length = 0.9, 0.3, 0.15
    ax.annotate(
        "N",
        color="white",
        xy=(x, y),
        xytext=(x, y - arrow_length),
        arrowprops=dict(facecolor="white", edgecolor="white", width=5, headwidth=15),
        ha="center",
        va="center",
        fontsize=10,
        xycoords=ax.transAxes,
    )

    return fig, ax

# 30m DEM of houston to use as example
with rio.open(pgf.dem_path) as ds:
    dem = ds.read(1)
    dem_profile = ds.profile
    dem[dem == dem_profile["nodata"]] = np.nan

# UTM 15N Easting, Northing of a grid cell in the ocean
ocean_E, ocean_N = 317540, 3272260

fig, ax = plot_raster(
    raster=dem,
    profile=dem_profile,
    label="Elevation [m] NAVD88",
    interpolation="nearest",
    vmax=30,
    vmin=0,
    cmap="terrain",
)

ax.plot(ocean_E, ocean_N, "ro", label="Ocean Pixel")

# add labels
ax.legend(loc="upper left")
ax.set(
    title="USGS 1 arc-second DEM",
    xlabel="UTM 15N Easting [m]",
    ylabel="UTM 15N Northing [m]",
)

plt.show()

# %% [markdown]
# ### run c-HAND

# %%
ocean_pixel = (ocean_E, ocean_N)
ike_gage = 3.8  # meters NAVD88
pgf.c_hand(ocean_coords=ocean_pixel, gage_el=ike_gage)
# Out:
# Running c_hand with parameters:
#     ocean_coords = (317540, 3272260)
#     xy = True
#     gage_el = 3.8
#     custom_dem = None
#     custom_path = None
# Coastal inundation raster written to data/houston_example_DEM_30m_coastal_inundation.tif
# c_hand completed in 7.6033 seconds

# %% [markdown]
# ### Crop out coastline and plot coastal inundation map

# %%
# read coastal inundation map
with rio.open(pgf.coastal_inundation_path) as ds:
    inun_ike = ds.read(1)
    ike_profile = ds.profile

# read geojson or shapefile of domain with coastline
aoi_coast = gpd.read_file(Path("data", "aoi_coastline.geojson"))
aoi_coast_mask = geometry_mask(
    aoi_coast.geometry,
    inun_ike.shape,
    dem_profile["transform"],
)
# crop array to coastline
inun_ike[aoi_coast_mask == True] = np.nan
inun_ike[inun_ike == 0] = np.nan

fig, ax = plot_raster(
    raster=inun_ike,
    profile=ike_profile,
    label="Inundation Depth [m]",
    interpolation="nearest",
    cmap="Blues",
    vmax=ike_gage,
    vmin=0,
)

# add labels
ax.set(
    title="Hazard Map",
    xlabel="UTM 15N Easting [m]",
    ylabel="UTM 15N Northing [m]",
)

plt.show()

# save figure
fig.savefig(Path("data", "inun_ike.png"), dpi=200, bbox_inches="tight")
